# %% [markdown]
# # **Intent Classification**

# %%
#first import
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

#second import sklearn dependencies
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

nltk.download("punkt_tab")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
training_data =[
    ("hello","greet"),
    ("hi there","greet"),
    ("good morning","greet"),
    ("hey","greet"),

    ("what's the weather today","weather"),
    ("how's the weather","weather"),
    ("what's the forecast for tomorrow","weather"),
    ("is it raining","weather"),
    ("tell me weather","weather"),

    ("open","open_app"),
    ("open google","open_app"),
    ("open youtube","open_app"),

    ("play","play_music"),
    ("play music","play_music"),
    ("play song","play_music"),

    ("bye","exit"),
    ("goodbye","exit"),
    ("see you later","exit")
]

# %%
sentences =[]
labels = []
for text,intent in training_data:
  sentences.append(text)
  labels.append(intent)
print("Sentences:",sentences)
print("Labels:",labels)
# Out:
# Sentences: ['hello', 'hi there', 'good morning', 'hey', "what's the weather today", "how's the weather", "what's the forecast for tomorrow", 'is it raining', 'tell me weather', 'open', 'open google', 'open youtube', 'play', 'play music', 'play song', 'bye', 'goodbye', 'see you later']
# Labels: ['greet', 'greet', 'greet', 'greet', 'weather', 'weather', 'weather', 'weather', 'weather', 'open_app', 'open_app', 'open_app', 'play_music', 'play_music', 'play_music', 'exit', 'exit', 'exit']

# %%
import string
punc=string.punctuation
def preprocess_text(sentences):
    cleaned_sentences = []
    for sentence in sentences:
        text = sentence.lower()
        tokens = word_tokenize(text)
        punctuation_filter = [word for word in tokens if word not in punc]
        eng_stopwords = stopwords.words("english")
        filtered_tokens = [word for word in punctuation_filter if word not in eng_stopwords]
        wnet = WordNetLemmatizer()
        lemmatized_words = []
        for word in filtered_tokens:
            lemmatized_words.append(wnet.lemmatize(word,"v"))
        cleaned_text = " ".join(lemmatized_words)
        cleaned_sentences.append(cleaned_text)
    return cleaned_sentences

# %%
clean_data=preprocess_text(sentences)
print(clean_data)
# Out:
# ['hello', 'hi', 'good morning', 'hey', "'s weather today", "'s weather", "'s forecast tomorrow", 'rain', 'tell weather', 'open', 'open google', 'open youtube', 'play', 'play music', 'play song', 'bye', 'goodbye', 'see later']

# %%
vectorizer= TfidfVectorizer()
X=vectorizer.fit_transform(clean_data)
print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 27 stored elements and shape (18, 21)>
#   Coords	Values
#   (0, 5)	1.0
#   (1, 7)	1.0
#   (2, 2)	0.7071067811865475
#   (2, 9)	0.7071067811865475
#   (3, 6)	1.0
#   (4, 19)	0.6183531995515883
#   (4, 17)	0.7859003248531672
#   (5, 19)	1.0
#   (6, 1)	0.7071067811865475
#   (6, 18)	0.7071067811865475
#   (7, 13)	1.0
#   (8, 19)	0.6183531995515883
#   (8, 16)	0.7859003248531672
#   (9, 11)	1.0
#   (10, 11)	0.6183531995515883
#   (10, 4)	0.7859003248531672
#   (11, 11)	0.6183531995515883
#   (11, 20)	0.7859003248531672
#   (12, 12)	1.0
#   (13, 12)	0.6183531995515883
#   (13, 10)	0.7859003248531672
#   (14, 12)	0.6183531995515883
#   (14, 15)	0.7859003248531672
#   (15, 0)	1.0
#   (16, 3)	1.0
#   (17, 14)	0.7071067811865475
#   (17, 8)	0.7071067811865475

# %%
logistic = LogisticRegression()
logistic.fit(X,labels)
# Out:
# LogisticRegression()

# %%
user_input="hello weather"
processed = preprocess_text([user_input])
user_vector= vectorizer.transform(processed)
prediction=logistic.predict(user_vector)
print(prediction)
# Out:
# ['weather']
