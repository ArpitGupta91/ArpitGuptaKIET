# %%
# !pip install opencv-python

# %%
# cv2 is the standard library alias used for OpenCV in python
# we get all the major image processing functions from cv2
import cv2

# %%
img = cv2.imread("KL Rahul.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (334, 500, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
cv2.imshow("Rahul",img)
# Wait indefinitelt until a key is pressed
# 0 means wait forever
# without this , the window will close immediately
cv2.waitKey(0)
#close all openCV windows
#important to release memory
cv2.destroyAllWindows()

# %%
# Convert image into grayscale
gray = cv2.cvtColor(img,cv2.COLOR_BRG2GRAY)
cv2.imshow("Og Rahul",gray)
cv.waitKey(0)
cv2.destroyAllWindows()

# %%
# Pixel Manipulation
# ROI - Region of interest
# Drawing shapes and text
