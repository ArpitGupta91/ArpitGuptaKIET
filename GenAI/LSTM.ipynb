# %%
import os
os.environ["KAGGLE_USERNAME"] ="arpitgupta91"
os.environ["KAGGLE_KEY"]= "KGAT_3116bb04a5135b94d82628b70a5bc6b7"
os.system("kaggle datasets download purusinghvi/email-spam-classification-dataset")
# Out:
# 1

# %%
import zipfile

with zipfile.ZipFile("email-spam-classification-dataset.zip", "r") as zip_ref:
    zip_ref.extractall("data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import zipfile
# ----> 3 with zipfile.ZipFile("email-spam-classification-dataset.zip", "r") as zip_ref:
#       4     zip_ref.extractall("data")
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'email-spam-classification-dataset.zip'
